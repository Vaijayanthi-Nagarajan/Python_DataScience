# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba_new = nba[["Name","Team","Position"]]

# %%
nba_new.drop(["Position"],axis = 1)
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
nba_new.drop(3)
# Out:
#               Name            Team Position
# 0    Avery Bradley  Boston Celtics       PG
# 1      Jae Crowder  Boston Celtics       SF
# 2     John Holland  Boston Celtics       SG
# 4    Jonas Jerebko  Boston Celtics       PF
# 5     Amir Johnson  Boston Celtics       PF
# ..             ...             ...      ...
# 453   Shelvin Mack       Utah Jazz       PG
# 454      Raul Neto       Utah Jazz       PG
# 455   Tibor Pleiss       Utah Jazz        C
# 456    Jeff Withey       Utah Jazz        C
# 457            NaN             NaN      NaN
#
# [457 rows x 3 columns]

# %%
incre = nba["Salary"]*2

# %%
nba["incre"] = nba["Salary"] * 2

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary       incre
# ...

# %%
data = {
         "Name": ["Ramesh","Suresh","Hari","Hrishi","Rahul"],
         "Age" : [23,32,26,18,14],
         "Marks" : [76,78,98,99,97]         
        }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age  Marks
# 0  Ramesh   23     76
# 1  Suresh   32     78
# 2    Hari   26     98
# 3  Hrishi   18     99
# 4   Rahul   14     97

# %%
new_row = {
          "Name" : "Selvi",
           "Age" :  25,
           "Marks": 98
}

# %%
df.loc[len(df)] = new_row

# %%
df
# Out:
#      Name  Age  Marks
# 0  Ramesh   23     76
# 1  Suresh   32     78
# 2    Hari   26     98
# 3  Hrishi   18     99
# 4   Rahul   14     97
# 5   Selvi   25     98

# %%
nba[10:20]
# Out:
#                        Name            Team  Number Position   Age Height  \
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# 12              Evan Turner  Boston Celtics    11.0       SG  27.0    6-7
# 13              James Young  Boston Celtics    13.0       SG  20.0    6-6
# 14             Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0
# 15         Bojan Bogdanovic   Brooklyn Nets    44.0       SG  27.0    6-8
# 16             Markel Brown   Brooklyn Nets    22.0       SG  24.0    6-3
# 17          Wayne Ellington   Brooklyn Nets    21.0       SG  28.0    6-4
# 18  Rondae Hollis-Jefferson   Brooklyn Nets    24.0       SG  21.0    6-7
# 19             Jarrett Jack   Brooklyn Nets     2.0       PG  32.0    6-3
#
#     Weight         College     Salary       incre
# 10   260.0      Ohio State  2569260.0   5138520.0
# 11   185.0      Washington  6912869.0  13825738.0
# ...

# %%
value_counts method

# %%
nba["Position"].value_counts(normalize ="True")
# Out:
# Position
# SG    0.223195
# PF    0.218818
# PG    0.201313
# SF    0.185996
# C     0.170678
# Name: proportion, dtype: float64

# %%
nba.dropna(how="all")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary       incre
# ...

# %%
nba.dropna(subset= ["College","Salary"])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary       incre
# 0            Texas  7730337.0  15460674.0
# ...

# %%
nba["Salary"].fillna(0)
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            0.0
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          0.0
# Name: Salary, Length: 458, dtype: float64

# %%
nba["College"] = nba["College"].fillna("Unknown")

# %%
nba["Salary"] = nba["Salary"].fillna(me)

# %%
me = nba["Salary"].mean()

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
nba["Salary"].astype("int")
# Out:
# 0      7730337
# 1      6796117
# 2      4842684
# 3      1148640
# 4      5000000
#         ...
# 453    2433333
# 454     900000
# 455    2900000
# 456     947276
# 457    4842684
# Name: Salary, Length: 458, dtype: int32

# %%
nba["Team"].nunique()
# Out:
# 30

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"].astype("category")
# Out:
# 0       PG
# 1       SF
# 2       SG
# 3       SG
# 4       PF
#       ...
# 453     PG
# 454     PG
# 455      C
# 456      C
# 457    NaN
# Name: Position, Length: 458, dtype: category
# Categories (5, object): ['C', 'PF', 'PG', 'SF', 'SG']

# %%
nba["Position"].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C', nan], dtype=object)

# %%
employees = pd.read_csv("Data/employees.csv")

# %%
employees
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
nba.dropna(subset = ["College","Salary"])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
nba["Salary"] = nba["Salary"].fillna(nba["Salary"].mean())

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
# astype method I

# %%
nba["Salary"] = nba["Salary"].astype("int")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    458 non-null    int32
# dtypes: float64(3), int32(1), object(5)
# memory usage: 30.5+ KB

# %%
nba["Age"] = nba["Age"].fillna(method = "ffill").astype("int")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    458 non-null    int32
# dtypes: float64(2), int32(2), object(5)
# memory usage: 28.8+ KB

# %%
nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C   26    7-0   231.0
# 457            NaN             NaN     NaN      NaN   26    NaN     NaN
#
#                College   Salary
# 0                Texas  7730337
# 1            Marquette  6796117
# ...

# %%
nba["Team"].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz',
#        nan], dtype=object)

# %%
nba["Team"].nunique()
# Out:
# 30

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C', nan], dtype=object)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    458 non-null    int32
# dtypes: float64(2), int32(2), object(5)
# memory usage: 28.8+ KB

# %%
nba["Position"]=nba["Position"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       458 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    458 non-null    int32
# dtypes: category(1), float64(2), int32(2), object(4)
# memory usage: 25.8+ KB

# %%
df = {
    "Name" : ["Hari","Hrishi","Rahul"],
    "Marks" : [87,89,96],
    "MS"   :["Married", "UM","UM"]
}

# %%
data = pd.DataFrame(df)

# %%
data
# Out:
#      Name  Marks       MS
# 0    Hari     87  Married
# 1  Hrishi     89       UM
# 2   Rahul     96       UM

# %%
data.loc[len(data)] = {"Name": "Anitha","Marks":"87","MS" : "Married"}

# %%
data
# Out:
#      Name Marks       MS
# 0    Hari    87  Married
# 1  Hrishi    89       UM
# 2   Rahul    96       UM
# 3  Anitha    87  Married

# %%
# sort_values method
# rank method

# %%
nba["Salary"] = nba["Salary"].sort_values()

# %%
nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C   26    7-0   231.0
# 457            NaN             NaN     NaN      NaN   26    NaN     NaN
#
#                College   Salary
# 0                Texas  7730337
# 1            Marquette  6796117
# ...

# %%
nba.sort_values(["Team","College"],ascending =[True, False],na_position = "first")
# Out:
#                 Name                Team  Number Position  Age Height  Weight  \
# 457              NaN                 NaN     NaN      NaN   26    NaN     NaN
# 318  Dennis Schroder       Atlanta Hawks    17.0       PG   22    6-1   172.0
# 320  Thabo Sefolosha       Atlanta Hawks    25.0       SF   32    6-7   220.0
# 321   Tiago Splitter       Atlanta Hawks    11.0        C   31   6-11   245.0
# 322   Walter Tavares       Atlanta Hawks    22.0        C   24    7-3   260.0
# ..               ...                 ...     ...      ...  ...    ...     ...
# 376  Markieff Morris  Washington Wizards     5.0       PF   26   6-10   245.0
# 377  Kelly Oubre Jr.  Washington Wizards    12.0       SF   20    6-7   205.0
# 378  Otto Porter Jr.  Washington Wizards    22.0       SF   23    6-8   198.0
# 369     Bradley Beal  Washington Wizards     3.0       SG   22    6-5   207.0
# 370     Jared Dudley  Washington Wizards     1.0       SF   30    6-7   225.0
#
#             College   Salary
# ...

# %%
nba["Salary"] =  nba["Salary"].sort_values(ascending = False)

# %%
nba
# Out:
#                        Name                  Team  Number Position  Age  \
# 109             Kobe Bryant    Los Angeles Lakers    24.0       SF   37
# 169            LeBron James   Cleveland Cavaliers    23.0       SF   31
# 33          Carmelo Anthony       New York Knicks     7.0       SF   32
# 251           Dwight Howard       Houston Rockets    12.0        C   30
# 339              Chris Bosh            Miami Heat     1.0       PF   32
# ..                      ...                   ...     ...      ...  ...
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG   25
# 135           Alan Williams          Phoenix Suns    15.0        C   23
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG   27
# 130            Phil Pressey          Phoenix Suns    25.0       PG   25
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF   23
#
#     Height  Weight           College    Salary
# 109    6-6   212.0               NaN  25000000
# ...

# %%
nba["Sal_rank"] = nba["Salary"].rank(ascending = False)

# %%
nba["Age_rank"] = nba["Age"].rank(method = "min")

# %%
nba = nba.sort_values("Age")

# %%
nba
# Out:
#                    Name                    Team  Number Position  Age Height  \
# 226       Rashad Vaughn         Milwaukee Bucks    20.0       SG   19    6-6
# 122        Devin Booker            Phoenix Suns     1.0       SG   19    6-6
# 356        Aaron Gordon           Orlando Magic     0.0       PF   20    6-9
# 40   Kristaps Porzingis         New York Knicks     6.0       PF   20    7-3
# 427     Cliff Alexander  Portland Trail Blazers    34.0       PF   20    6-8
# ..                  ...                     ...     ...      ...  ...    ...
# 261        Vince Carter       Memphis Grizzlies    15.0       SG   39    6-6
# 102      Pablo Prigioni    Los Angeles Clippers     9.0       PG   39    6-3
# 304        Andre Miller       San Antonio Spurs    24.0       PG   40    6-3
# 298          Tim Duncan       San Antonio Spurs    21.0        C   40   6-11
# 400       Kevin Garnett  Minnesota Timberwolves    21.0       PF   40   6-11
#
# ...
